# %% [markdown]
# # Grid Search with dask ml
#
# ```cmd
# conda install dask-ml -y
# ```

# %%
conda install -c conda-forge graphviz ipycytoscape
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - conda-forge
#  - rapidsai
#  - pytorch
#  - nvidia
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.3.0
#     latest version: 24.4.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - graphviz
#     - ipycytoscape
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     atk-1.0-2.38.0             |       hd4edc92_1         539 KB  conda-forge
#     fribidi-1.0.10             |       h36c2ea0_0         112 KB  conda-forge
#     gdk-pixbuf-2.42.10         |       h829c605_5         560 KB  conda-forge
#     graphviz-9.0.0             |       h78e8752_1         2.2 MB  conda-forge
#     gtk2-2.24.33               |       h280cfa0_4         6.2 MB  conda-forge
#     gts-0.7.6                  |       h977cf35_4         311 KB  conda-forge
#     ipycytoscape-1.3.3         |     pyhd8ed1ab_1         2.9 MB  conda-forge
#     libgd-2.3.3                |       h119a65a_9         219 KB  conda-forge
#     librsvg-2.56.3             |       he3f83f7_1         5.6 MB  conda-forge
#     pango-1.52.1               |       ha41ecd1_0         434 KB  conda-forge
#     spectate-1.0.1             |     pyhd8ed1ab_0          16 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        19.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   atk-1.0            conda-forge/linux-64::atk-1.0-2.38.0-hd4edc92_1
#   fribidi            conda-forge/linux-64::fribidi-1.0.10-h36c2ea0_0
#   gdk-pixbuf         conda-forge/linux-64::gdk-pixbuf-2.42.10-h829c605_5
#   graphviz           conda-forge/linux-64::graphviz-9.0.0-h78e8752_1
#   gtk2               conda-forge/linux-64::gtk2-2.24.33-h280cfa0_4
#   gts                conda-forge/linux-64::gts-0.7.6-h977cf35_4
#   ipycytoscape       conda-forge/noarch::ipycytoscape-1.3.3-pyhd8ed1ab_1
#   libgd              conda-forge/linux-64::libgd-2.3.3-h119a65a_9
#   librsvg            conda-forge/linux-64::librsvg-2.56.3-he3f83f7_1
#   pango              conda-forge/linux-64::pango-1.52.1-ha41ecd1_0
#   spectate           conda-forge/noarch::spectate-1.0.1-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages:
# gtk2-2.24.33         | 6.2 MB    |                                       |   0%
# librsvg-2.56.3       | 5.6 MB    |                                       |   0%
#
# ipycytoscape-1.3.3   | 2.9 MB    |                                       |   0%
#
#
# graphviz-9.0.0       | 2.2 MB    |                                       |   0%
#
#
#
# gdk-pixbuf-2.42.10   | 560 KB    |                                       |   0%
#
#
#
#
# atk-1.0-2.38.0       | 539 KB    |                                       |   0%
#
#
#
#
#
# pango-1.52.1         | 434 KB    |                                       |   0%
#
#
#
#
#
#
# gts-0.7.6            | 311 KB    |                                       |   0%
#
#
#
#
#
#
#
# libgd-2.3.3          | 219 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# fribidi-1.0.10       | 112 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# spectate-1.0.1       | 16 KB     |                                       |   0%
#
#
#
# gdk-pixbuf-2.42.10   | 560 KB    | ######3                               |  17%
# librsvg-2.56.3       | 5.6 MB    | 1                                     |   0%
#
#
# gtk2-2.24.33         | 6.2 MB    |                                       |   0%
#
#
#
# gdk-pixbuf-2.42.10   | 560 KB    | #############################6        |  80%
#
# ipycytoscape-1.3.3   | 2.9 MB    | 1                                     |   1%
# librsvg-2.56.3       | 5.6 MB    | 8                                     |   2%
#
#
# gtk2-2.24.33         | 6.2 MB    | 6                                     |   2%
#
# ipycytoscape-1.3.3   | 2.9 MB    | ####1                                 |  11%
# librsvg-2.56.3       | 5.6 MB    | ###                                   |   8%
#
#
#
# gdk-pixbuf-2.42.10   | 560 KB    | ##################################### | 100%
#
#
# gtk2-2.24.33         | 6.2 MB    | #9                                    |   5%
#
#
#
#
# atk-1.0-2.38.0       | 539 KB    | #                                     |   3%
# librsvg-2.56.3       | 5.6 MB    | ####4                                 |  12%
#
# ipycytoscape-1.3.3   | 2.9 MB    | ######5                               |  18%
#
#
# gtk2-2.24.33         | 6.2 MB    | ##7                                   |   7%
#
#
#
#
# atk-1.0-2.38.0       | 539 KB    | ############                          |  33%
#
# ipycytoscape-1.3.3   | 2.9 MB    | ##########4                           |  28%
# librsvg-2.56.3       | 5.6 MB    | ######2                               |  17%
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | ####3                                 |  12%
#
#
# graphviz-9.0.0       | 2.2 MB    | ##################6                   |  50%
#
#
#
#
# atk-1.0-2.38.0       | 539 KB    | ##################################### | 100%
# gtk2-2.24.33         | 6.2 MB    | ######                                |  16%
#
#
# graphviz-9.0.0       | 2.2 MB    | #######################               |  62%
#
# ipycytoscape-1.3.3   | 2.9 MB    | ##############5                       |  39%
#
#
#
#
#
# pango-1.52.1         | 434 KB    | #3                                    |   4%
# gtk2-2.24.33         | 6.2 MB    | #######3                              |  20%
#
# ipycytoscape-1.3.3   | 2.9 MB    | ##################5                   |  50%
#
#
# graphviz-9.0.0       | 2.2 MB    | ###########################2          |  74%
#
#
#
#
#
# pango-1.52.1         | 434 KB    | ##########9                           |  30%
# librsvg-2.56.3       | 5.6 MB    | ##########8                           |  29%
#
# ipycytoscape-1.3.3   | 2.9 MB    | #####################8                |  59%
#
#
# graphviz-9.0.0       | 2.2 MB    | ##############################9       |  84%
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | ########6                             |  23%
# librsvg-2.56.3       | 5.6 MB    | ############2                         |  33%
#
# gtk2-2.24.33         | 6.2 MB    | ##########4                           |  28%
#
#
#
#
#
#
# gts-0.7.6            | 311 KB    | #9                                    |   5%
#
#
#
#
#
# pango-1.52.1         | 434 KB    | ##################################### | 100%
#
#
# graphviz-9.0.0       | 2.2 MB    | ##################################### | 100%
#
#
# graphviz-9.0.0       | 2.2 MB    | ##################################### | 100%
# librsvg-2.56.3       | 5.6 MB    | #############8                        |  38%
#
# ipycytoscape-1.3.3   | 2.9 MB    | ####################################6 |  99%
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | ###########7                          |  32%
#
#
#
#
#
#
# gts-0.7.6            | 311 KB    | ################################3     |  88%
#
#
#
#
#
#
# gts-0.7.6            | 311 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# fribidi-1.0.10       | 112 KB    | #####2                                |  14%
#
#
#
#
#
#
#
#
# fribidi-1.0.10       | 112 KB    | ##################################### | 100%
# librsvg-2.56.3       | 5.6 MB    | ###############6                      |  42%
#
#
#
#
#
#
#
# libgd-2.3.3          | 219 KB    | ################################4     |  88%
#
#
#
#
#
#
#
#
#
# gtk2-2.24.33         | 6.2 MB    | #############3                        |  36%
#
#
#
#
#
#
#
#
#
# spectate-1.0.1       | 16 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# libgd-2.3.3          | 219 KB    | ##################################### | 100%
# gtk2-2.24.33         | 6.2 MB    | ##############7                       |  40%
#
# ipycytoscape-1.3.3   | 2.9 MB    | ##################################### | 100%
# gtk2-2.24.33         | 6.2 MB    | ################3                     |  44%
# gtk2-2.24.33         | 6.2 MB    | ##################7                   |  51%
# gtk2-2.24.33         | 6.2 MB    | #####################9                |  59%
# gtk2-2.24.33         | 6.2 MB    | ##########################            |  70%
# gtk2-2.24.33         | 6.2 MB    | ##############################        |  81%
# gtk2-2.24.33         | 6.2 MB    | ##################################    |  92%
# librsvg-2.56.3       | 5.6 MB    | ################################      |  87%
# gtk2-2.24.33         | 6.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: |
# /
# done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install dask-ml -y
# Out:
# Channels:
#  - rapidsai
#  - pytorch
#  - conda-forge
#  - nvidia
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.3.0
#     latest version: 24.4.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - dask-ml
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     dask-ml-2024.3.20          |     pyhd8ed1ab_0         110 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         110 KB
#
# The following packages will be UPDATED:
#
#   dask-ml                            2023.3.24-pyhd8ed1ab_1 --> 2024.3.20-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages:
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import time

import cupy as cp

import cudf
import dask
import dask_cudf
import dask.dataframe as dd
dask.config.set({"dataframe.backend": "cudf"})

from dask_ml.model_selection import  GridSearchCV as GSCV
from cuml.model_selection import train_test_split, GridSearchCV
from cuml.metrics import accuracy_score

import xgboost as xgb
from xgboost import XGBClassifier

# %%
class Timer:
    def __init__(self, name="cpu"):
        self.name = name
        
    def __enter__(self):
        self.start = time.perf_counter()
        
    def __exit__(self, type, value, trackback):
        self.end = time.perf_counter()
        self.execute_time = self.end - self.start
        print(f"{self.name} execute time : {self.execute_time:.4f} seconds")

# %%
with Timer(name="dask read parquet") as dask_time:
    train_dask = dd.read_parquet("./data/train.parquet")
    test_dask  = dd.read_parquet("./data/test.parquet")
# Out:
# dask read parquet execute time : 0.1484 seconds

# %%
def preprocess_data(data):
    # Convert categorical variables into numerical
    data = dd.reshape.get_dummies(data.categorize(), columns=["Sex", "Embarked"])
    # Fill missing values in Age and Fare with median
    data["Age"] = data["Age"].fillna(data["Age"].median())
    data["Fare"] = data["Fare"].fillna(data["Fare"].median())
    # Drop unnecessary columns
    data = data.drop(["PassengerId", "Name", "Ticket", "Cabin"], axis=1)
    return data

# %%
train_dask = train_dask.persist()
test_dask  = test_dask.persist()
# Out:
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()

# %%
with Timer(name="dask preprocessed") as dask_time:
    train_dask = preprocess_data(train_dask)
    test_dask  = preprocess_data(test_dask)
# Out:
# dask preprocessed execute time : 0.7610 seconds

# %%
train_dask.visualize()
# Out:
# CytoscapeWidget(cytoscape_layout={'name': 'dagre', 'rankDir': 'BT', 'nodeSep': 10, 'edgeSep': 10, 'spacingFact…

# %%
train_dask = train_dask.persist()
test_dask  = test_dask.persist()

# %%
with Timer(name="Train Valid Split") as dask_time:
    X_train = train_dask.drop("Survived", axis=1).compute()
    y_train = train_dask["Survived"].compute()
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
# Out:
# Train Valid Split execute time : 0.0649 seconds

# %%
model = XGBClassifier(tree_method = "hist", device = "cuda")

param_grid = {
    "max_depth": [10,30,50],
    "min_child_weight" : [1,3,6,10],
    "n_estimators": [200,300,500,1000],
    "learning_rate": [0.1, 0.01, 0.001],
}

# %%
with Timer(name="grid search with xgb") as dask_time:
    # Perform grid search to find the best hyperparameters
    grid_search = GSCV(model, param_grid, cv=5, scoring='accuracy')
    X_train = X_train.astype(int)
    try:
        grid_search.fit(X_train, y_train.to_numpy())
    except KeyboardInterrupt:
        print("Grid search interrupted by user.")

    # Get the best model
    best_model = grid_search.best_estimator_
# Out:
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# ...
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# grid search with xgb execute time : 3324.0267 seconds

# %% [markdown]
# grid search with xgb execute time : 3324.0267 seconds

# %%
test_dask
# Out:
# Dask Series Structure:
# npartitions=1
#     bool
#      ...
# dtype: bool
# Dask Name: apply, 2 graph layers

# %%
with Timer(name="xgb gpu inference") as dask_time:
    X_val = X_val.astype(int)
    y_pred_train = best_model.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_pred_train)
    print("Training Accuracy:", train_accuracy)
    
    y_pred_val = best_model.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_pred_val)
    print("Validation Accuracy:", val_accuracy)
# Out:
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# Training Accuracy: 0.8639551401138306
# Validation Accuracy: 0.7921348214149475
# xgb gpu inference execute time : 0.2536 seconds

# %%
def fix_bool(x):
    if x == -1:
        return False
    else:
        return bool(x)

test_dask = test_dask.apply(fix_bool, meta=bool, axis=1)
# Out:
# /opt/conda/lib/python3.11/site-packages/dask/dataframe/core.py:7364: FutureWarning: Meta is not valid, `map_partitions` and `map_overlap` expects output to be a pandas object. Try passing a pandas object as meta or a dict or tuple representing the (name, dtype) of the columns. In the future the meta you passed will not work.
#   warnings.warn(

# %%
test_predictions = best_model.predict(test_dask.compute())

# Prepare submission file
submission_df = cudf.DataFrame({
    "PassengerId": range(892, 892 + len(test_predictions)),
    "Survived": test_predictions
})

# Save submission file
submission_df.to_csv("submission_xgb.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/cudf/core/indexed_frame.py:3453, in IndexedFrame._apply(self, func, kernel_getter, *args, **kwargs)
#    3452 try:
# -> 3453     kernel, retty = _compile_or_get(
#    3454         self, func, args, kernel_getter=kernel_getter
#    3455     )
#    3456 except Exception as e:
#
# File /opt/conda/lib/python3.11/site-packages/nvtx/nvtx.py:116, in annotate.__call__.<locals>.inner(*args, **kwargs)
#     115 libnvtx_push_range(self.attributes, self.domain.handle)
# --> 116 result = func(*args, **kwargs)
#     117 libnvtx_pop_range(self.domain.handle)
#
# File /opt/conda/lib/python3.11/site-packages/cudf/core/udf/utils.py:274, in _compile_or_get(frame, func, args, kernel_getter, suffix)
#     271 # precompile the user udf to get the right return type.
#     272 # could be a MaskedType or a scalar type.
# --> 274 kernel, scalar_return_type = kernel_getter(frame, func, args)
#     275 np_return_type = (
#     276     numpy_support.as_dtype(scalar_return_type)
#     277     if scalar_return_type.is_internal
#     278     else scalar_return_type.np_dtype
#     279 )
#
# File /opt/conda/lib/python3.11/site-packages/cudf/core/udf/row_function.py:143, in _get_row_kernel(frame, func, args)
#     140 row_type = _get_frame_row_type(
#     141     np.dtype(list(_all_dtypes_from_frame(frame).items()))
#     142 )
# --> 143 scalar_return_type = _get_udf_return_type(row_type, func, args)
#     144 # this is the signature for the final full kernel compilation
#
# File /opt/conda/lib/python3.11/site-packages/nvtx/nvtx.py:116, in annotate.__call__.<locals>.inner(*args, **kwargs)
#     115 libnvtx_push_range(self.attributes, self.domain.handle)
# --> 116 result = func(*args, **kwargs)
#     117 libnvtx_pop_range(self.domain.handle)
#
# File /opt/conda/lib/python3.11/site-packages/cudf/core/udf/utils.py:94, in _get_udf_return_type(argty, func, args)
#      93 with _CUDFNumbaConfig():
# ---> 94     ptx, output_type = cudautils.compile_udf(func, compile_sig)
#      96 if not isinstance(output_type, MaskedType):
#
# File /opt/conda/lib/python3.11/site-packages/cudf/utils/cudautils.py:126, in compile_udf(udf, type_signature)
#     124 # We haven't compiled a function like this before, so need to fall back to
#     125 # compilation with Numba
# --> 126 ptx_code, return_type = cuda.compile_ptx_for_current_device(
#     127     udf, type_signature, device=True
#     128 )
#     129 if not isinstance(return_type, cudf.core.udf.masked_typing.MaskedType):
#
# File /opt/conda/lib/python3.11/site-packages/numba/cuda/compiler.py:351, in compile_ptx_for_current_device(pyfunc, sig, debug, lineinfo, device, fastmath, opt, abi, abi_info)
#     350 cc = get_current_device().compute_capability
# --> 351 return compile_ptx(pyfunc, sig, debug=debug, lineinfo=lineinfo,
#     352                    device=device, fastmath=fastmath, cc=cc, opt=opt,
#     353                    abi=abi, abi_info=abi_info)
#
# File /opt/conda/lib/python3.11/site-packages/numba/core/compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      34 with self:
# ---> 35     return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/numba/cuda/compiler.py:315, in compile_ptx(pyfunc, sig, debug, lineinfo, device, fastmath, cc, opt, abi, abi_info)
#     314 cc = cc or config.CUDA_DEFAULT_PTX_CC
# --> 315 cres = compile_cuda(pyfunc, return_type, args, debug=debug,
#     316                     lineinfo=lineinfo, fastmath=fastmath,
#     317                     nvvm_options=nvvm_options, cc=cc)
#     318 resty = cres.signature.return_type
#
# File /opt/conda/lib/python3.11/site-packages/numba/core/compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      34 with self:
# ---> 35     return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/numba/cuda/compiler.py:196, in compile_cuda(pyfunc, return_type, args, debug, lineinfo, inline, fastmath, nvvm_options, cc)
#     195 with target_override('cuda'):
# --> 196     cres = compiler.compile_extra(typingctx=typingctx,
#     197                                   targetctx=targetctx,
#     198                                   func=pyfunc,
#     199                                   args=args,
#     200                                   return_type=return_type,
#     201                                   flags=flags,
#     202                                   locals={},
#     203                                   pipeline_class=CUDACompiler)
#     205 library = cres.library
#
# File /opt/conda/lib/python3.11/site-packages/numba/core/compiler.py:751, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     749 pipeline = pipeline_class(typingctx, targetctx, library,
#     750                           args, return_type, flags, locals)
# --> 751 return pipeline.compile_extra(func)
#
# File /opt/conda/lib/python3.11/site-packages/numba/core/compiler.py:445, in CompilerBase.compile_extra(self, func)
#     444 self.state.lifted_from = None
# --> 445 return self._compile_bytecode()
#
# File /opt/conda/lib/python3.11/site-packages/numba/core/compiler.py:513, in CompilerBase._compile_bytecode(self)
#     512 assert self.state.func_ir is None
# --> 513 return self._compile_core()
#
# File /opt/conda/lib/python3.11/site-packages/numba/core/compiler.py:492, in CompilerBase._compile_core(self)
#     491         if is_final_pipeline:
# --> 492             raise e
#     493 else:
#
# File /opt/conda/lib/python3.11/site-packages/numba/core/compiler.py:479, in CompilerBase._compile_core(self)
#     478 try:
# --> 479     pm.run(self.state)
#     480     if self.state.cr is not None:
#
# File /opt/conda/lib/python3.11/site-packages/numba/core/compiler_machinery.py:368, in PassManager.run(self, state)
#     367 patched_exception = self._patch_error(msg, e)
# --> 368 raise patched_exception
#
# File /opt/conda/lib/python3.11/site-packages/numba/core/compiler_machinery.py:356, in PassManager.run(self, state)
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#
# File /opt/conda/lib/python3.11/site-packages/numba/core/compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      34 with self:
# ---> 35     return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/numba/core/compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#
# File /opt/conda/lib/python3.11/site-packages/numba/core/compiler_machinery.py:273, in PassManager._runPass.<locals>.check(func, compiler_state)
#     272 def check(func, compiler_state):
# --> 273     mangled = func(compiler_state)
#     274     if mangled not in (True, False):
#
# File /opt/conda/lib/python3.11/site-packages/numba/core/typed_passes.py:112, in BaseTypeInference.run_pass(self, state)
#     109 with fallback_context(state, 'Function "%s" failed type inference'
#     110                       % (state.func_id.func_name,)):
#     111     # Type inference
# --> 112     typemap, return_type, calltypes, errs = type_inference_stage(
#     113         state.typingctx,
#     114         state.targetctx,
#     115         state.func_ir,
#     116         state.args,
#     117         state.return_type,
#     118         state.locals,
#     119         raise_errors=self._raise_errors)
#     120     state.typemap = typemap
#
# File /opt/conda/lib/python3.11/site-packages/numba/core/typed_passes.py:93, in type_inference_stage(typingctx, targetctx, interp, args, return_type, locals, raise_errors)
#      92 # return errors in case of partial typing
# ---> 93 errs = infer.propagate(raise_errors=raise_errors)
#      94 typemap, restype, calltypes = infer.unify(raise_errors=raise_errors)
#
# File /opt/conda/lib/python3.11/site-packages/numba/core/typeinfer.py:1091, in TypeInferer.propagate(self, raise_errors)
#    1090 if not force_lit_args:
# -> 1091     raise errors[0]
#    1092 else:
#
# TypingError: Failed in cuda mode pipeline (step: nopython frontend)
# No implementation of function Function(<built-in function eq>) found for signature:
#
#  >>> eq(Record(Pclass[type=Masked(int64);offset=0],Age[type=Masked(float64);offset=16],SibSp[type=Masked(int64);offset=32],Parch[type=Masked(int64);offset=48],Fare[type=Masked(float64);offset=64],Sex_female[type=Masked(bool);offset=73],Sex_male[type=Masked(bool);offset=75],Embarked_C[type=Masked(bool);offset=77],Embarked_Q[type=Masked(bool);offset=79],Embarked_S[type=Masked(bool);offset=81];83;True), Literal[int](-1))
#
# There are 40 candidate implementations:
#   - Of which 38 did not match due to:
#   Overload of function 'eq': File: <numerous>: Line N/A.
#     With argument(s): '(Record(Pclass[type=Masked(int64);offset=0],Age[type=Masked(float64);offset=16],SibSp[type=Masked(int64);offset=32],Parch[type=Masked(int64);offset=48],Fare[type=Masked(float64);offset=64],Sex_female[type=Masked(bool);offset=73],Sex_male[type=Masked(bool);offset=75],Embarked_C[type=Masked(bool);offset=77],Embarked_Q[type=Masked(bool);offset=79],Embarked_S[type=Masked(bool);offset=81];83;True), int64)':
#    No match.
#   - Of which 2 did not match due to:
#   Operator Overload in function 'eq': File: unknown: Line unknown.
#     With argument(s): '(Record(Pclass[type=Masked(int64);offset=0],Age[type=Masked(float64);offset=16],SibSp[type=Masked(int64);offset=32],Parch[type=Masked(int64);offset=48],Fare[type=Masked(float64);offset=64],Sex_female[type=Masked(bool);offset=73],Sex_male[type=Masked(bool);offset=75],Embarked_C[type=Masked(bool);offset=77],Embarked_Q[type=Masked(bool);offset=79],Embarked_S[type=Masked(bool);offset=81];83;True), int64)':
#    No match for registered cases:
#     * (bool, bool) -> bool
#     * (int8, int8) -> bool
#     * (int16, int16) -> bool
#     * (int32, int32) -> bool
#     * (int64, int64) -> bool
#     * (uint8, uint8) -> bool
#     * (uint16, uint16) -> bool
#     * (uint32, uint32) -> bool
#     * (uint64, uint64) -> bool
#     * (float32, float32) -> bool
#     * (float64, float64) -> bool
#     * (complex64, complex64) -> bool
#     * (complex128, complex128) -> bool
#
# During: typing of intrinsic-call at /tmp/ipykernel_4919/279261101.py (2)
#
# File "../../../../tmp/ipykernel_4919/279261101.py", line 2:
# <source missing, REPL/exec in use?>
#
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 test_np = test_dask.compute().to_pandas().values
#       2 test_predictions = best_model.predict(test_np)
#       3 #test_predictions = best_model.predict(test_dask.compute())
#       4
#       5 # Prepare submission file
#
# File /opt/conda/lib/python3.11/site-packages/dask/base.py:379, in DaskMethodsMixin.compute(self, **kwargs)
#     355 def compute(self, **kwargs):
#     356     """Compute this dask collection
#     357
#     358     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     377     dask.compute
#     378     """
# --> 379     (result,) = compute(self, traverse=False, **kwargs)
#     380     return result
#
# File /opt/conda/lib/python3.11/site-packages/dask/base.py:665, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     662     postcomputes.append(x.__dask_postcompute__())
#     664 with shorten_traceback():
# --> 665     results = schedule(dsk, keys, **kwargs)
#     667 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /opt/conda/lib/python3.11/site-packages/nvtx/nvtx.py:116, in annotate.__call__.<locals>.inner(*args, **kwargs)
#     113 @wraps(func)
#     114 def inner(*args, **kwargs):
#     115     libnvtx_push_range(self.attributes, self.domain.handle)
# --> 116     result = func(*args, **kwargs)
#     117     libnvtx_pop_range(self.domain.handle)
#     118     return result
#
# File /opt/conda/lib/python3.11/site-packages/cudf/core/dataframe.py:4603, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    4600 if result_type is not None:
#    4601     raise ValueError("The `result_type` kwarg is not yet supported.")
# -> 4603 return self._apply(func, _get_row_kernel, *args, **kwargs)
#
# File /opt/conda/lib/python3.11/contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# File /opt/conda/lib/python3.11/site-packages/nvtx/nvtx.py:116, in annotate.__call__.<locals>.inner(*args, **kwargs)
#     113 @wraps(func)
#     114 def inner(*args, **kwargs):
#     115     libnvtx_push_range(self.attributes, self.domain.handle)
# --> 116     result = func(*args, **kwargs)
#     117     libnvtx_pop_range(self.domain.handle)
#     118     return result
#
# File /opt/conda/lib/python3.11/site-packages/cudf/core/indexed_frame.py:3457, in IndexedFrame._apply(self, func, kernel_getter, *args, **kwargs)
#    3453     kernel, retty = _compile_or_get(
#    3454         self, func, args, kernel_getter=kernel_getter
#    3455     )
#    3456 except Exception as e:
# -> 3457     raise ValueError(
#    3458         "user defined function compilation failed."
#    3459     ) from e
#    3461 # Mask and data column preallocated
#    3462 ans_col = _return_arr_from_dtype(retty, len(self))
#
# ValueError: user defined function compilation failed.

# %% [markdown]
# # CPU Example

# %%
model = XGBClassifier()

# Define hyperparameters to tune
param_grid = {
    "max_depth": [10,30,50],
    "min_child_weight" : [1,3,6,10],
    "n_estimators": [200,300,500,1000],
    "learning_rate": [0.1, 0.01, 0.001],
}

# %%
with Timer(name="grid search with xgb") as dask_time:
    # Perform grid search to find the best hyperparameters
    grid_search = GridSearchCV(XGBClassifier(), param_grid, cv=5, scoring='accuracy', verbose=1)
    X_train = X_train.astype(int)
    grid_search.fit(X_train, y_train.to_numpy())

    # Get the best model
    best_model = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [07:08:58] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1707159369174/work/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cpu, while the input data is on: cuda:0.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# ...
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# grid search with xgb execute time : 37076.7734 seconds

# %%
Fitting 5 folds for each of 144 candidates, totalling 720 fits
...
grid search with xgb execute time : 37076.7734 seconds
# Out:
#   Cell In[1], line 1
#     Fitting 5 folds for each of 144 candidates, totalling 720 fits
#             ^
# SyntaxError: invalid syntax

# %%
with Timer(name="xgb cpu inference") as dask_time:
    X_val = X_val.astype(int)
    y_pred_train = best_model.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_pred_train)
    print("Training Accuracy:", train_accuracy)
    
    y_pred_val = best_model.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_pred_val)
    print("Validation Accuracy:", val_accuracy)
# Out:
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:839: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   feature_names = data.columns.format()
# Training Accuracy: 0.8681626915931702
# Validation Accuracy: 0.7921348214149475
# xgb cpu inference execute time : 0.7041 seconds
